# %% [markdown]
# # OS python

# %% [markdown]
# Python has a built-in [os module](https://docs.python.org/3/library/os.html) that allows us to use operating system dependent functionality.
#
# You can get the current directory:

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\PC-GAM\\Downloads'

# %% [markdown]
# ### Listing Files in a Directory
#
# You can also use the os module to list directories.

# %%
# In your current directory
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '03-Opening and Reading Files Folders.ipynb',
#  'Compressed',
#  'desktop.ini',
#  'Documents',
#  'HW3 - Minoo Sayyadpour.docx',
#  'mmsegmentation-multi-layer-master',
#  'mmsegmentation-multi-layer-master.zip',
#  'MMSegmentation_on_Potsdam_Dataset.ipynb',
#  'Music',
#  'Part II_Chapter I_Section II_Operators.pptx',
#  'Part_II_III_IV_LinearOptimization_14021007.mp4',
#  'potsdam_mmsegmentation(1).ipynb',
#  'potsdam_mmsegmentation.ipynb',
#  'Programs',
#  'Telegram Desktop',
#  'Video',
#  'yadgyry-mashyn.pptx',
#  'دانلود potsdam.txt']

# %%
# In any directory you pass
os.listdir(r"C:\Users\PC-GAM\Downloads")
# Out:
# ['.ipynb_checkpoints',
#  '03-Opening and Reading Files Folders.ipynb',
#  'Compressed',
#  'desktop.ini',
#  'Documents',
#  'HW3 - Minoo Sayyadpour.docx',
#  'mmsegmentation-multi-layer-master',
#  'mmsegmentation-multi-layer-master.zip',
#  'MMSegmentation_on_Potsdam_Dataset.ipynb',
#  'Music',
#  'old.txt',
#  'Part II_Chapter I_Section II_Operators.pptx',
#  'Part_II_III_IV_LinearOptimization_14021007.mp4',
#  'potsdam_mmsegmentation(1).ipynb',
#  'potsdam_mmsegmentation.ipynb',
#  'Programs',
#  'Telegram Desktop',
#  'Video',
#  'yadgyry-mashyn.pptx',
#  'دانلود potsdam.txt']

# %%
os.rename('old.txt','new.txt')

# %%
os.listdir(r"C:\Users\PC-GAM\Downloads")
# Out:
# ['.ipynb_checkpoints',
#  '03-Opening and Reading Files Folders.ipynb',
#  'Compressed',
#  'desktop.ini',
#  'Documents',
#  'HW3 - Minoo Sayyadpour.docx',
#  'mmsegmentation-multi-layer-master',
#  'mmsegmentation-multi-layer-master.zip',
#  'MMSegmentation_on_Potsdam_Dataset.ipynb',
#  'Music',
#  'new.txt',
#  'Part II_Chapter I_Section II_Operators.pptx',
#  'Part_II_III_IV_LinearOptimization_14021007.mp4',
#  'potsdam_mmsegmentation(1).ipynb',
#  'potsdam_mmsegmentation.ipynb',
#  'Programs',
#  'Telegram Desktop',
#  'Video',
#  'yadgyry-mashyn.pptx',
#  'دانلود potsdam.txt']

# %%
os.chdir('..')
os.listdir()
# Out:
# ['.anaconda',
#  '.android',
#  '.codeium',
#  '.conda',
#  '.condarc',
#  '.continuum',
#  '.gitconfig',
#  '.idlerc',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.matplotlib',
#  '.ms-ad',
#  '.spyder-py3',
#  '.vscode',
#  'anaconda3',
#  'AppData',
#  'Application Data',
#  'Contacts',
#  'Cookies',
#  'Desktop',
#  'Documents',
#  'Downloads',
#  'Favorites',
#  'Links',
#  'Local Settings',
#  'Music',
#  'My Documents',
#  'NetHood',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{2ad838bc-efea-11ee-a54d-000d3a94eaa1}.TM.blf',
#  'NTUSER.DAT{2ad838bc-efea-11ee-a54d-000d3a94eaa1}.TMContainer00000000000000000001.regtrans-ms',
#  'NTUSER.DAT{2ad838bc-efea-11ee-a54d-000d3a94eaa1}.TMContainer00000000000000000002.regtrans-ms',
#  'ntuser.ini',
#  'OneDrive',
#  'PrintHood',
#  'PycharmProjects',
#  'Recent',
#  'Saved Games',
#  'Searches',
#  'SendTo',
#  'Start Menu',
#  'Templates',
#  'v2rayN',
#  'Videos']

# %%
os.stat('new.txt')
# Out:
# os.stat_result(st_mode=33206, st_ino=26458647810894707, st_dev=6372254348265350650, st_nlink=1, st_uid=0, st_gid=0, st_size=0, st_atime=1764108434, st_mtime=1764108423, st_ctime=1764108423)

# %% [markdown]
# ### Moving Files
#
# You can use the built-in **shutil** module to to move files to different locations. Keep in mind, there are permission restrictions, for example if you are logged in a User A, you won't be able to make changes to the top level Users folder without the proper permissions.

# %%
import shutil

# %%
shutil.move('practice.txt','C:\\Users\\Marcial')
# Out:
# 'C:\\Users\\Marcial\\practice.txt'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '00-Collections-Module.ipynb',
#  '01-Datetime-Module.ipynb',
#  '01-Opening-and-Reading-Files.ipynb',
#  '02-Math-and-Random-Module.ipynb',
#  '03-Python Debugger (pdb).ipynb',
#  '04-Timing your code - timeit.ipynb',
#  '05-Overview-of-Regular-Expressions.ipynb',
#  '06-Unzipping-and-Zipping-Files.ipynb',
#  '07-OS-Module.ipynb',
#  '08-Advanced-Python-Module-Exercise',
#  'comp_file.zip',
#  'Example_Top_Level',
#  'extracted_content',
#  'new_file.txt',
#  'new_file2.txt']

# %%
shutil.move('C:\\Users\\Marcial\practice.txt',os.getcwd())
# Out:
# 'C:\\Users\\Marcial\\Pierian-Data-Courses\\Complete-Python-3-Bootcamp\\12-Advanced Python Modules\\practice.txt'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '00-Collections-Module.ipynb',
#  '01-Datetime-Module.ipynb',
#  '01-Opening-and-Reading-Files.ipynb',
#  '02-Math-and-Random-Module.ipynb',
#  '03-Python Debugger (pdb).ipynb',
#  '04-Timing your code - timeit.ipynb',
#  '05-Overview-of-Regular-Expressions.ipynb',
#  '06-Unzipping-and-Zipping-Files.ipynb',
#  '07-OS-Module.ipynb',
#  '08-Advanced-Python-Module-Exercise',
#  'comp_file.zip',
#  'Example_Top_Level',
#  'extracted_content',
#  'new_file.txt',
#  'new_file2.txt',
#  'practice.txt']

# %% [markdown]
# ### Deleting Files
# ____
# **NOTE: The os module provides 3 methods for deleting files:**
# * os.unlink(path) which deletes a file at the path your provide
# * os.rmdir(path) which deletes a folder (folder must be empty) at the path your provide
# * shutil.rmtree(path) this is the most dangerous, as it will remove all files and folders contained in the path.
# * **All of these methods can not be reversed! Which means if you make a mistake you won't be able to recover the file. Instead we will use the send2trash module. A safer alternative that sends deleted files to the trash bin instead of permanent removal.**
# ___
#
# Install the send2trash module with:
#
#     pip install send2trash
#
# at your command line.

# %%
import send2trash

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '00-Collections-Module.ipynb',
#  '01-Datetime-Module.ipynb',
#  '01-Opening-and-Reading-Files.ipynb',
#  '02-Math-and-Random-Module.ipynb',
#  '03-Python Debugger (pdb).ipynb',
#  '04-Timing your code - timeit.ipynb',
#  '05-Overview-of-Regular-Expressions.ipynb',
#  '06-Unzipping-and-Zipping-Files.ipynb',
#  '07-OS-Module.ipynb',
#  '08-Advanced-Python-Module-Exercise',
#  'comp_file.zip',
#  'Example_Top_Level',
#  'extracted_content',
#  'new_file.txt',
#  'new_file2.txt',
#  'practice.txt']

# %%
send2trash.send2trash('practice.txt')

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '00-Collections-Module.ipynb',
#  '01-Datetime-Module.ipynb',
#  '01-Opening-and-Reading-Files.ipynb',
#  '02-Math-and-Random-Module.ipynb',
#  '03-Python Debugger (pdb).ipynb',
#  '04-Timing your code - timeit.ipynb',
#  '05-Overview-of-Regular-Expressions.ipynb',
#  '06-Unzipping-and-Zipping-Files.ipynb',
#  '07-OS-Module.ipynb',
#  '08-Advanced-Python-Module-Exercise',
#  'comp_file.zip',
#  'Example_Top_Level',
#  'extracted_content',
#  'new_file.txt',
#  'new_file2.txt']

# %%
os.chdir(r"C:\Users\PC-GAM\Downloads")
os.rmdir('mmsegmentation-multi-layer-master')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[27], line 2
#       1 os.chdir(r"C:\Users\PC-GAM\Downloads")
# ----> 2 os.rmdir('mmsegmentation-multi-layer-master')
#
# OSError: [WinError 145] The directory is not empty: 'mmsegmentation-multi-layer-master'

# %% [markdown]
# ### Walking through a directory
#
# Often you will just need to "walk" through a directory, that is visit every file or folder and check to see if a file is in the directory, and then perhaps do something with that file. Usually recursively walking through every file and folder in a directory would be quite tricky to program, but luckily the os module has a direct method call for this called os.walk().

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Marcial\\Pierian-Data-Courses\\Complete-Python-3-Bootcamp\\12-Advanced Python Modules'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '00-Collections-Module.ipynb',
#  '01-Datetime-Module.ipynb',
#  '01-Opening-and-Reading-Files.ipynb',
#  '02-Math-and-Random-Module.ipynb',
#  '03-Python Debugger (pdb).ipynb',
#  '04-Timing your code - timeit.ipynb',
#  '05-Overview-of-Regular-Expressions.ipynb',
#  '06-Unzipping-and-Zipping-Files.ipynb',
#  '07-OS-Module.ipynb',
#  '08-Advanced-Python-Module-Exercise',
#  'comp_file.zip',
#  'Example_Top_Level',
#  'extracted_content',
#  'new_file.txt',
#  'new_file2.txt']

# %%
if os.path.exists('mmsegmentation-multi-layer-master'):
    os.chdir('mmsegmentation-multi-layer-master')

# %%
print(os.getcwd())
# Out:
# C:\Users\PC-GAM\Downloads\mmsegmentation-multi-layer-master

# %%
for folder , sub_folders , files in os.walk("Example_Top_Level"):
    
    print("Currently looking at folder: "+ folder)
    print('\n')
    print("THE SUBFOLDERS ARE: ")
    for sub_fold in sub_folders:
        print("\t Subfolder: "+sub_fold )
    
    print('\n')
    
    print("THE FILES ARE: ")
    for f in files:
        print("\t File: "+f)
    print('\n')
    
    # Now look at subfolders
# Out:
# Currently looking at folder: Example_Top_Level
#
#
# THE SUBFOLDERS ARE:
# 	 Subfolder: Mid-Example-One
# 	 Subfolder: Mid-Example-Two
#
#
# THE FILES ARE:
# 	 File: Mid-Example.txt
#
#
# Currently looking at folder: Example_Top_Level\Mid-Example-One
#
#
# THE SUBFOLDERS ARE:
# 	 Subfolder: Bottom-Level-One
# 	 Subfolder: Bottom-Level-Two
#
#
# THE FILES ARE:
# 	 File: Mid-Level-Doc.txt
#
#
# Currently looking at folder: Example_Top_Level\Mid-Example-One\Bottom-Level-One
#
#
# THE SUBFOLDERS ARE:
#
#
# THE FILES ARE:
# 	 File: One_Text.txt
#
#
# Currently looking at folder: Example_Top_Level\Mid-Example-One\Bottom-Level-Two
#
#
# THE SUBFOLDERS ARE:
#
#
# THE FILES ARE:
# 	 File: Bottom-Text-Two.txt
#
#
# Currently looking at folder: Example_Top_Level\Mid-Example-Two
#
#
# THE SUBFOLDERS ARE:
#
#
# THE FILES ARE:

# %%
def remove_dir(directory):
    for folder , sub_folders , files in os.walk(directory, topdown=False):
        for file in files:
            os.remove(os.path.join(folder,file))
        for dir in sub_folders:
            os.rmdir(os.path.join(folder,dir))
    os.rmdir(directory)

# %%
os.system('fsutil volume diskfree c: > fsutil.txt')
with open('fsutil.txt','r') as file:
    content = file.read()
    print(content)
# Out:
# Error 5: Access is denied.

# %%
def run_cmd(command, file='res.txt'):
    os.system(f'{cmd} > {file}')
    with open(f'{file}','r') as f:
        content = f.read()
        print(content)

# %%
output = os.popen('ping 8.8.8.8')
op = output.read()
output.close()
print(op)
# Out:
# Pinging 8.8.8.8 with 32 bytes of data:
# Reply from 192.168.1.103: Destination host unreachable.
# Reply from 192.168.1.103: Destination host unreachable.
# Reply from 192.168.1.103: Destination host unreachable.
# Reply from 192.168.1.103: Destination host unreachable.
#
# Ping statistics for 8.8.8.8:
#     Packets: Sent = 4, Received = 4, Lost = 0 (0% loss),

# %%
os.chmod('res.txt',0o740)

# %% [markdown]
# ___
# Excellent, you should now be aware of how to work with a computer's files and folders in whichever directory they are in. Remember that the os module works for any operating system that supports Python, which means these commands will work across Linux,MacOs, or Windows without need for adjustment.
